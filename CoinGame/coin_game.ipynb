# %%
#!pip install tabulate
from coin_game_env import CoinGameEnv
from input_agent import InputAgent
from random_agent import RandomAgent
from minimax_agent import MinimaxAgent
from play import play_vs_other_agent
from UONI import UONI

# %%
env = CoinGameEnv(grid_size=5)
input_agent = InputAgent()

# %% [markdown]
# Input Agents

# %%
#play_vs_other_agent(env, agent1=input_agent, agent2=input_agent, render=True)

# %% [markdown]
# Random Agents

# %%
play_vs_other_agent(env, agent1=RandomAgent(1), agent2=RandomAgent(2), render=True)
# Out:
# +-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+
# |     | 0   | 1   | 2   | 3   | 4   | 5   | 6   | 7   | 8   |
# +=====+=====+=====+=====+=====+=====+=====+=====+=====+=====+
# |   0 |     |     |     |     | O   |     |     |     |     |
# +-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+
# |   1 |     |     |     | O   | O   | O   |     |     |     |
# +-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+
# |   2 |     |     | O   | O   | O   | O   | O   |     |     |
# +-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+
# |   3 |     | O   | O   | O   |     | O   | O   | O   |     |
# +-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+
# |   4 | O   | O   | O   | O   | O   | O   |     | O   | O   |
# +-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+
# +-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+
# |     | 0   | 1   | 2   | 3   | 4   | 5   | 6   | 7   | 8   |
# +=====+=====+=====+=====+=====+=====+=====+=====+=====+=====+
# |   0 |     |     |     |     | O   |     |     |     |     |
# +-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+
# |   1 |     |     |     | O   | O   |     |     |     |     |
# +-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+
# |   2 |     |     | O   | O   | O   | O   | O   |     |     |
# +-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+
# |   3 |     | O   | O   | O   |     | O   | O   | O   |     |
# +-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+
# |   4 | O   | O   | O   | O   | O   | O   |     | O   | O   |
# +-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+
# +-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+
# |     | 0   | 1   | 2   | 3   | 4   | 5   | 6   | 7   | 8   |
# +=====+=====+=====+=====+=====+=====+=====+=====+=====+=====+
# |   0 |     |     |     |     | O   |     |     |     |     |
# +-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+
# |   1 |     |     |     | O   | O   |     |     |     |     |
# +-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+
# |   2 |     |     | O   | O   | O   | O   | O   |     |     |
# +-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+
# |   3 |     | O   | O   | O   |     | O   | O   | O   |     |
# +-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+
# |   4 | O   | O   | O   |     | O   | O   |     | O   | O   |
# +-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+
# +-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+
# |     | 0   | 1   | 2   | 3   | 4   | 5   | 6   | 7   | 8   |
# +=====+=====+=====+=====+=====+=====+=====+=====+=====+=====+
# |   0 |     |     |     |     | O   |     |     |     |     |
# +-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+
# |   1 |     |     |     | O   | O   |     |     |     |     |
# +-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+
# |   2 |     |     | O   |     | O   | O   | O   |     |     |
# +-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+
# |   3 |     | O   | O   | O   |     | O   | O   | O   |     |
# +-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+
# |   4 | O   | O   | O   |     | O   | O   |     | O   | O   |
# +-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+
# +-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+
# |     | 0   | 1   | 2   | 3   | 4   | 5   | 6   | 7   | 8   |
# +=====+=====+=====+=====+=====+=====+=====+=====+=====+=====+
# |   0 |     |     |     |     | O   |     |     |     |     |
# +-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+
# |   1 |     |     |     | O   |     |     |     |     |     |
# +-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+
# |   2 |     |     | O   |     | O   | O   | O   |     |     |
# +-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+
# |   3 |     | O   | O   | O   |     | O   | O   | O   |     |
# +-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+
# |   4 | O   | O   | O   |     | O   | O   |     | O   | O   |
# +-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+
# +-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+
# |     | 0   | 1   | 2   | 3   | 4   | 5   | 6   | 7   | 8   |
# +=====+=====+=====+=====+=====+=====+=====+=====+=====+=====+
# |   0 |     |     |     |     | O   |     |     |     |     |
# +-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+
# |   1 |     |     |     | O   |     |     |     |     |     |
# +-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+
# |   2 |     |     | O   |     | O   | O   | O   |     |     |
# +-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+
# |   3 |     | O   | O   | O   |     | O   | O   | O   |     |
# +-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+
# |   4 | O   | O   | O   |     |     | O   |     | O   | O   |
# +-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+
# +-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+
# |     | 0   | 1   | 2   | 3   | 4   | 5   | 6   | 7   | 8   |
# +=====+=====+=====+=====+=====+=====+=====+=====+=====+=====+
# |   0 |     |     |     |     | O   |     |     |     |     |
# +-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+
# |   1 |     |     |     | O   |     |     |     |     |     |
# +-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+
# |   2 |     |     | O   |     | O   | O   | O   |     |     |
# +-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+
# |   3 |     | O   | O   | O   |     |     | O   | O   |     |
# +-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+
# |   4 | O   | O   | O   |     |     | O   |     | O   | O   |
# +-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+
# +-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+
# |     | 0   | 1   | 2   | 3   | 4   | 5   | 6   | 7   | 8   |
# +=====+=====+=====+=====+=====+=====+=====+=====+=====+=====+
# |   0 |     |     |     |     | O   |     |     |     |     |
# +-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+
# |   1 |     |     |     | O   |     |     |     |     |     |
# +-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+
# |   2 |     |     | O   |     | O   |     | O   |     |     |
# +-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+
# |   3 |     | O   | O   | O   |     |     | O   | O   |     |
# +-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+
# |   4 | O   | O   | O   |     |     | O   |     | O   | O   |
# +-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+
# +-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+
# |     | 0   | 1   | 2   | 3   | 4   | 5   | 6   | 7   | 8   |
# +=====+=====+=====+=====+=====+=====+=====+=====+=====+=====+
# |   0 |     |     |     |     | O   |     |     |     |     |
# +-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+
# |   1 |     |     |     | O   |     |     |     |     |     |
# +-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+
# |   2 |     |     | O   |     | O   |     | O   |     |     |
# +-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+
# |   3 |     | O   | O   | O   |     |     | O   | O   |     |
# +-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+
# |   4 | O   | O   | O   |     |     | O   |     | O   |     |
# +-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+
# +-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+
# |     | 0   | 1   | 2   | 3   | 4   | 5   | 6   | 7   | 8   |
# +=====+=====+=====+=====+=====+=====+=====+=====+=====+=====+
# |   0 |     |     |     |     | O   |     |     |     |     |
# +-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+
# |   1 |     |     |     | O   |     |     |     |     |     |
# +-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+
# |   2 |     |     | O   |     | O   |     | O   |     |     |
# +-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+
# |   3 |     | O   |     |     |     |     | O   | O   |     |
# +-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+
# |   4 | O   | O   | O   |     |     | O   |     | O   |     |
# +-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+
# +-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+
# |     | 0   | 1   | 2   | 3   | 4   | 5   | 6   | 7   | 8   |
# +=====+=====+=====+=====+=====+=====+=====+=====+=====+=====+
# |   0 |     |     |     |     | O   |     |     |     |     |
# +-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+
# |   1 |     |     |     | O   |     |     |     |     |     |
# +-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+
# |   2 |     |     | O   |     |     |     | O   |     |     |
# +-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+
# |   3 |     | O   |     |     |     |     | O   | O   |     |
# +-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+
# |   4 | O   | O   | O   |     |     | O   |     | O   |     |
# +-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+
# +-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+
# |     | 0   | 1   | 2   | 3   | 4   | 5   | 6   | 7   | 8   |
# +=====+=====+=====+=====+=====+=====+=====+=====+=====+=====+
# |   0 |     |     |     |     | O   |     |     |     |     |
# +-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+
# |   1 |     |     |     | O   |     |     |     |     |     |
# +-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+
# |   2 |     |     | O   |     |     |     | O   |     |     |
# +-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+
# |   3 |     | O   |     |     |     |     | O   | O   |     |
# +-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+
# |   4 | O   |     |     |     |     | O   |     | O   |     |
# +-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+
# +-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+
# |     | 0   | 1   | 2   | 3   | 4   | 5   | 6   | 7   | 8   |
# +=====+=====+=====+=====+=====+=====+=====+=====+=====+=====+
# |   0 |     |     |     |     | O   |     |     |     |     |
# +-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+
# |   1 |     |     |     | O   |     |     |     |     |     |
# +-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+
# |   2 |     |     | O   |     |     |     | O   |     |     |
# +-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+
# |   3 |     | O   |     |     |     |     | O   |     |     |
# +-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+
# |   4 | O   |     |     |     |     | O   |     | O   |     |
# +-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+
# +-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+
# |     | 0   | 1   | 2   | 3   | 4   | 5   | 6   | 7   | 8   |
# +=====+=====+=====+=====+=====+=====+=====+=====+=====+=====+
# |   0 |     |     |     |     |     |     |     |     |     |
# +-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+
# |   1 |     |     |     | O   |     |     |     |     |     |
# +-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+
# |   2 |     |     | O   |     |     |     | O   |     |     |
# +-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+
# |   3 |     | O   |     |     |     |     | O   |     |     |
# +-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+
# |   4 | O   |     |     |     |     | O   |     | O   |     |
# +-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+
# +-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+
# |     | 0   | 1   | 2   | 3   | 4   | 5   | 6   | 7   | 8   |
# +=====+=====+=====+=====+=====+=====+=====+=====+=====+=====+
# |   0 |     |     |     |     |     |     |     |     |     |
# +-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+
# |   1 |     |     |     | O   |     |     |     |     |     |
# +-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+
# |   2 |     |     | O   |     |     |     |     |     |     |
# +-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+
# |   3 |     | O   |     |     |     |     | O   |     |     |
# +-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+
# |   4 | O   |     |     |     |     | O   |     | O   |     |
# +-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+
# +-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+
# |     | 0   | 1   | 2   | 3   | 4   | 5   | 6   | 7   | 8   |
# +=====+=====+=====+=====+=====+=====+=====+=====+=====+=====+
# |   0 |     |     |     |     |     |     |     |     |     |
# +-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+
# |   1 |     |     |     | O   |     |     |     |     |     |
# +-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+
# |   2 |     |     | O   |     |     |     |     |     |     |
# +-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+
# |   3 |     | O   |     |     |     |     |     |     |     |
# +-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+
# |   4 | O   |     |     |     |     | O   |     | O   |     |
# +-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+
# +-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+
# |     | 0   | 1   | 2   | 3   | 4   | 5   | 6   | 7   | 8   |
# +=====+=====+=====+=====+=====+=====+=====+=====+=====+=====+
# |   0 |     |     |     |     |     |     |     |     |     |
# +-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+
# |   1 |     |     |     | O   |     |     |     |     |     |
# +-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+
# |   2 |     |     | O   |     |     |     |     |     |     |
# +-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+
# |   3 |     | O   |     |     |     |     |     |     |     |
# +-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+
# |   4 |     |     |     |     |     | O   |     | O   |     |
# +-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+
# +-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+
# |     | 0   | 1   | 2   | 3   | 4   | 5   | 6   | 7   | 8   |
# +=====+=====+=====+=====+=====+=====+=====+=====+=====+=====+
# |   0 |     |     |     |     |     |     |     |     |     |
# +-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+
# |   1 |     |     |     |     |     |     |     |     |     |
# +-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+
# |   2 |     |     | O   |     |     |     |     |     |     |
# +-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+
# |   3 |     | O   |     |     |     |     |     |     |     |
# +-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+
# |   4 |     |     |     |     |     | O   |     | O   |     |
# +-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+
# +-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+
# |     | 0   | 1   | 2   | 3   | 4   | 5   | 6   | 7   | 8   |
# +=====+=====+=====+=====+=====+=====+=====+=====+=====+=====+
# |   0 |     |     |     |     |     |     |     |     |     |
# +-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+
# |   1 |     |     |     |     |     |     |     |     |     |
# +-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+
# |   2 |     |     |     |     |     |     |     |     |     |
# +-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+
# |   3 |     | O   |     |     |     |     |     |     |     |
# +-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+
# |   4 |     |     |     |     |     | O   |     | O   |     |
# +-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+
# +-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+
# |     | 0   | 1   | 2   | 3   | 4   | 5   | 6   | 7   | 8   |
# +=====+=====+=====+=====+=====+=====+=====+=====+=====+=====+
# |   0 |     |     |     |     |     |     |     |     |     |
# +-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+
# |   1 |     |     |     |     |     |     |     |     |     |
# +-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+
# |   2 |     |     |     |     |     |     |     |     |     |
# +-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+
# |   3 |     |     |     |     |     |     |     |     |     |
# +-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+
# |   4 |     |     |     |     |     | O   |     | O   |     |
# +-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+
# +-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+
# |     | 0   | 1   | 2   | 3   | 4   | 5   | 6   | 7   | 8   |
# +=====+=====+=====+=====+=====+=====+=====+=====+=====+=====+
# |   0 |     |     |     |     |     |     |     |     |     |
# +-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+
# |   1 |     |     |     |     |     |     |     |     |     |
# +-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+
# |   2 |     |     |     |     |     |     |     |     |     |
# +-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+
# |   3 |     |     |     |     |     |     |     |     |     |
# +-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+
# |   4 |     |     |     |     |     |     |     | O   |     |
# +-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+
# 2

# %% [markdown]
# Random Agent vs UONI (Universal Optimization Neural Interface)

# %%
import matplotlib.pyplot as plt
# Assuming ws is a list of winners
def print_graph(ws, level):
    winners = ["UONI", "OTHER"]
    win_counts = [ws.count(x) for x in [1,2]]

    plt.bar(winners, win_counts)
    plt.xlabel('Winner Number ' + level)
    plt.ylabel('Win Amount')
    plt.title('Win Amount per Winner')
    plt.show()

# %%
from tqdm import tqdm
ws = {'easy':[], 'medium':[], 'hard':[]}
for level in ['easy', 'medium', 'hard']:
    for i in tqdm(range(20)):
        if i%2 == 0:
            ws[level].append(play_vs_other_agent(env, agent1=UONI(1, level), agent2=RandomAgent(2), render=False))
        else:
            ws[level].append(3-play_vs_other_agent(env, agent1=RandomAgent(1), agent2=UONI(2, level), render=False))
    print_graph(ws[level], level)
# Out:
# 100%|██████████| 20/20 [00:00<00:00, 33.80it/s]
# 100%|██████████| 20/20 [00:00<00:00, 22.22it/s]
# 100%|██████████| 20/20 [00:01<00:00, 16.20it/s]

# %% [markdown]
# Minimax

# %%
play_vs_other_agent(env, agent1=RandomAgent(1), agent2=MinimaxAgent(2), render=True)
# Out:
# +-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+
# |     | 0   | 1   | 2   | 3   | 4   | 5   | 6   | 7   | 8   |
# +=====+=====+=====+=====+=====+=====+=====+=====+=====+=====+
# |   0 |     |     |     |     | O   |     |     |     |     |
# +-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+
# |   1 |     |     |     | O   | O   | O   |     |     |     |
# +-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+
# |   2 |     |     | O   |     | O   | O   | O   |     |     |
# +-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+
# |   3 |     | O   | O   | O   | O   | O   | O   | O   |     |
# +-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+
# |   4 | O   | O   | O   | O   | O   | O   | O   | O   | O   |
# +-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+
# +-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+
# |     | 0   | 1   | 2   | 3   | 4   | 5   | 6   | 7   | 8   |
# +=====+=====+=====+=====+=====+=====+=====+=====+=====+=====+
# |   0 |     |     |     |     | O   |     |     |     |     |
# +-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+
# |   1 |     |     |     | O   |     | O   |     |     |     |
# +-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+
# |   2 |     |     | O   |     | O   | O   | O   |     |     |
# +-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+
# |   3 |     | O   | O   | O   | O   | O   | O   | O   |     |
# +-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+
# |   4 | O   | O   | O   | O   | O   | O   | O   | O   | O   |
# +-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+
# +-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+
# |     | 0   | 1   | 2   | 3   | 4   | 5   | 6   | 7   | 8   |
# +=====+=====+=====+=====+=====+=====+=====+=====+=====+=====+
# |   0 |     |     |     |     | O   |     |     |     |     |
# +-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+
# |   1 |     |     |     | O   |     | O   |     |     |     |
# +-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+
# |   2 |     |     | O   |     | O   | O   | O   |     |     |
# +-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+
# |   3 |     | O   | O   | O   | O   | O   | O   | O   |     |
# +-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+
# |   4 | O   | O   | O   | O   | O   | O   | O   | O   | O   |
# +-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+
# aca
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 play_vs_other_agent(env, agent1=RandomAgent(1), agent2=MinimaxAgent(2), render=True)
#
# File c:\Users\Dell-PC\Desktop\Josefina\ORT\Semestre-7\Inteligencia Artificial\OBLIGATORIO\Obligatorio-IA\CoinGame\play.py:19, in play_vs_other_agent(env, agent1, agent2, render)
#      17     if not done:
#      18         next_action = agent2.next_action(obs)
# ---> 19         _, _, done, winner, _ = env.step(next_action)
#      21 if render: env.render()
#      23 return winner
#
# File c:\Users\Dell-PC\Desktop\Josefina\ORT\Semestre-7\Inteligencia Artificial\OBLIGATORIO\Obligatorio-IA\CoinGame\coin_game_env.py:23, in CoinGameEnv.step(self, action)
#      22 def step(self, action):
# ---> 23     action_done = self.grid.play(action)
#      25     if action_done:
#      26         self.next_player()
#
# File c:\Users\Dell-PC\Desktop\Josefina\ORT\Semestre-7\Inteligencia Artificial\OBLIGATORIO\Obligatorio-IA\CoinGame\board.py:22, in Board.play(self, action)
#      20 def play(self, action):
#      21     """Realiza una jugada en el tablero"""
# ---> 22     row = action[0]
#      23     from_col = action[1]
#      24     to_col = action[2]
#
# TypeError: 'NoneType' object is not subscriptable

# %%
import matplotlib.pyplot as plt
# Assuming ws is a list of winners
def minimax_graph(ws, level):
    winners = ["UONI", "Minimax"]
    win_counts = [ws.count(x) for x in [1,2]]

    plt.bar(winners, win_counts)
    plt.xlabel('Winner Number ' + level)
    plt.ylabel('Win Amount')
    plt.title('Win Amount per Winner')
    plt.show()

# %%
from tqdm import tqdm
ws = {'easy':[], 'medium':[], 'hard':[]}
for level in ['easy', 'medium', 'hard']:
    for i in tqdm(range(20)):
        if i%2 == 0:
            ws[level].append(play_vs_other_agent(env, agent1=UONI(1, level), agent2=MinimaxAgent(2), render=False))
        else:
            ws[level].append(3-play_vs_other_agent(env, agent1=MinimaxAgent(1), agent2=UONI(2, level), render=False))
    minimax_graph(ws[level], level)
# Out:
# 100%|██████████| 20/20 [00:01<00:00, 17.34it/s]
# 100%|██████████| 20/20 [00:01<00:00, 10.89it/s]
# 100%|██████████| 20/20 [00:01<00:00, 10.06it/s]

# %% [markdown]
# Expectimax
